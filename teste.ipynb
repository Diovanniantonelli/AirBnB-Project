# %%
import pandas as pd

# %%
df = pd.read_csv('dados.csv')
display(df)
# Out:
#         Unnamed: 0  host_is_superhost  host_listings_count   latitude  \
# 0                1                  1                  2.0 -22.965919
# 1                3                  0                  3.0 -22.977117
# 2                4                  1                  1.0 -22.983024
# 3                5                  1                  1.0 -22.988165
# 4                6                  1                  1.0 -22.981269
# ...            ...                ...                  ...        ...
# 557635      902204                  0                  1.0 -22.986030
# 557636      902205                  0                  0.0 -23.003180
# 557637      902206                  0                  0.0 -22.966640
# 557638      902208                  0                  0.0 -23.003400
# 557639      902209                  0                  5.0 -23.010560
#
#         longitude  accommodates  bathrooms  bedrooms  beds  extra_people  ...  \
# ...
